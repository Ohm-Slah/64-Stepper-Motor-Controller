# %%
import numpy as np
from IPython.display import Audio
import matplotlib.pyplot as plt
from scipy.io import wavfile
# %matplotlib notebook

# %%
fs, ys = wavfile.read("trumpet_chirp.wav")

# %%
Audio(ys, rate = fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def plot_signal_frequency(ys, f1, f2, fs = 44100):
    N  = ys.size
    L = N/fs
    yk = np.fft.fft(ys)
    k = np.arange(N)
    freqs = k/L
    fig, ax = plt.subplots()
    ax.plot(freqs, np.abs(yk))
    ax.set_xlim(f1, f2)
    ax.set_xlabel("Frequency (Hz)")
    ax.set_ylabel("|yk|")

# %%
plot_signal_frequency(ys, 0, 10000)
# Out:
# <div id='626e6ef4-4b01-49c6-a2e3-8baa8b3be189'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 plot_signal_frequency(ys, 0, 10000)
#
# Cell In [8], line 10, in plot_signal_frequency(ys, f1, f2, fs)
#       8 ax.plot(freqs, np.abs(yk))
#       9 ax.set_xlim(f1, f2)
# ---> 10 ax.set_x_label("Frequency (Hz)")
#      11 ax.set_ylabel("|yk|")
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_x_label'
